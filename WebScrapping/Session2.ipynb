# %% [markdown]
# ## Working with Websites that have JS interaction

# %%
import requests
from bs4 import BeautifulSoup
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
url="https://www.naukri.com/data-science-jobs"
resp=requests.get(url,headers=headers).text
print(resp)
# Out:
# <!DOCTYPE html> <html lang="en"> <head> <meta http-equiv="X-UA-Compatible" content="IE=Edge" /> <meta name="viewport" content="width=device-width,initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" /> <link rel="dns-prefetch preconnect" href="//static.naukri.com"> <link rel="dns-prefetch preconnect" href="//img.naukri.com"> <link rel="dns-prefetch preconnect" href="//logs.naukri.com"> <link rel="dns-prefetch preconnect" href="//lg.naukri.com"> <link rel="dns-prefetch" href="https://www.googletagmanager.com" /> <base href="//www.naukri.com" /> <link rel="manifest" href="./manifest.json"> <link rel="preload" as="style" href="//static.naukri.com/s/7/109/c/main.f59532c6.min.css"/> <link rel="preload" as="script" href="//static.naukri.com/s/7/109/j/main.3d561068.min.js"> <script>
#         window.ipAddress = "www.naukri.com";
#         window.DEBUG = true;
#         window.appId = 135;
#                     var isCrawler = false;
#                             var ucBrowser = false;
#             </script>   <style type="text/css"> .splScrn{ height: 100%; } body{margin:0} .nkIcon { width: 9rem; margin: auto; position: relative; padding-top: 95px; } #circleG { width: 9rem; margin: auto } .circleG { background-color: #2DABE2; float: left; height: 14px; margin: 5px; width: 14px; animation-name: bounce_circleG; -o-animation-name: bounce_circleG; -ms-animation-name: bounce_circleG; -webkit-animation-name: bounce_circleG; -moz-animation-name: bounce_circleG; animation-duration: 1.8s; -o-animation-duration: 1.8s; -ms-animation-duration: 1.8s; -webkit-animation-duration: 1.8s; -moz-animation-duration: 1.8s; animation-iteration-count: infinite; -o-animation-iteration-count: infinite; -ms-animation-iteration-count: infinite; -webkit-animation-iteration-count: infinite; -moz-animation-iteration-count: infinite; animation-direction: normal; -o-animation-direction: normal; -ms-animation-direction: normal; -webkit-animation-direction: normal; -moz-animation-direction: normal; border-radius: 50%; -o-border-radius: 50%; -ms-border-radius: 50%; -webkit-border-radius: 50%; -moz-border-radius: 50% } #root, body, html { height: 100% } #circleG_1 { animation-delay: .45s; -o-animation-delay: .45s; -ms-animation-delay: .45s; -webkit-animation-delay: .45s; -moz-animation-delay: .45s } #circleG_2 { animation-delay: .65s; -o-animation-delay: .65s; -ms-animation-delay: .65s; -webkit-animation-delay: .65s; -moz-animation-delay: .65s } #circleG_3 { animation-delay: .85s; -o-animation-delay: .85s; -ms-animation-delay: .85s; -webkit-animation-delay: .85s; -moz-animation-delay: .85s } #circleG_4 { animation-delay: 1.05s; -o-animation-delay: 1.05s; -ms-animation-delay: 1.05s; -webkit-animation-delay: 1.05s; -moz-animation-delay: 1.05s } #circleG_5 { animation-delay: 1.25s; -o-animation-delay: 1.25s; -ms-animation-delay: 1.25s; -webkit-animation-delay: 1.25s; -moz-animation-delay: 1.25s } @keyframes bounce_circleG { 50% { width: 10px; height: 10px; margin: 7px; background-color: rgba(12, 109, 182, 0) } } </style> </head> <body>  <noscript> <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NX744H"height="0" width="0" style="display:none;visibility:hidden"></iframe> </noscript>  <div id="root"> <div class="splScrn"> <div class="row top"> <div class="nkIcon"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 315 315"><style type="text/css"> .st0{fill:#2DABE2;} .st1{fill:#0C6DB6;} .st2{fill:#EC2227;} .st3{fill:#444444;} .st4{fill-rule:evenodd;clip-rule:evenodd;fill:#EC2227;} .st5{fill-rule:evenodd;clip-rule:evenodd;fill:#0C6DB6;} </style><path class="st0" d="M0 200.8h10v4.6c1.5-1.9 3-3.2 4.5-4 1.5-0.8 3.4-1.2 5.6-1.2 3 0 5.3 0.9 7 2.7 1.7 1.8 2.5 4.5 2.5 8.2v17.8H18.8v-15.4c0-1.8-0.3-3-1-3.7 -0.7-0.7-1.6-1.1-2.7-1.1 -1.3 0-2.4 0.5-3.2 1.5 -0.8 1-1.2 2.8-1.2 5.3v13.4H0V200.8z"/><path class="st0" d="M45.8 209.9l-10.3-1.1c0.4-1.8 0.9-3.2 1.7-4.2 0.7-1 1.8-1.9 3.2-2.7 1-0.5 2.3-1 4.1-1.3 1.7-0.3 3.6-0.4 5.6-0.4 3.2 0 5.8 0.2 7.8 0.5 2 0.4 3.6 1.1 4.9 2.3 0.9 0.8 1.6 1.9 2.2 3.4 0.5 1.5 0.8 2.8 0.8 4.2v12.4c0 1.3 0.1 2.4 0.3 3.1 0.2 0.7 0.5 1.7 1.1 2.9H56.9c-0.4-0.7-0.7-1.3-0.8-1.6 -0.1-0.4-0.2-1-0.4-1.8 -1.4 1.4-2.8 2.3-4.2 2.9 -1.9 0.8-4.1 1.2-6.6 1.2 -3.3 0-5.9-0.8-7.6-2.3 -1.7-1.5-2.6-3.5-2.6-5.7 0-2.1 0.6-3.9 1.9-5.2 1.2-1.4 3.6-2.4 6.9-3.1 4-0.8 6.6-1.4 7.8-1.7 1.2-0.3 2.5-0.8 3.8-1.3 0-1.3-0.3-2.2-0.8-2.8 -0.5-0.5-1.5-0.8-2.9-0.8 -1.8 0-3.1 0.3-4 0.8C46.8 207.8 46.2 208.6 45.8 209.9zM55.1 215.5c-1.5 0.5-3 1-4.6 1.4 -2.2 0.6-3.6 1.2-4.1 1.7 -0.6 0.6-0.9 1.2-0.9 2 0 0.8 0.3 1.5 0.9 2.1 0.6 0.5 1.5 0.8 2.6 0.8 1.2 0 2.3-0.3 3.3-0.9 1-0.6 1.8-1.3 2.2-2.1 0.4-0.8 0.6-1.9 0.6-3.3V215.5z"/><path class="st0" d="M101.6 228.8h-10v-4.5c-1.5 1.9-3 3.2-4.5 4 -1.5 0.8-3.4 1.2-5.6 1.2 -3 0-5.3-0.9-6.9-2.7 -1.7-1.8-2.5-4.5-2.5-8.2v-17.8h10.8v15.4c0 1.8 0.3 3 1 3.7 0.7 0.7 1.6 1.1 2.7 1.1 1.3 0 2.3-0.5 3.2-1.5 0.8-1 1.2-2.8 1.2-5.3v-13.5h10.7V228.8z"/><path class="st0" d="M108.1 190.1h11v20l8-9.3h13.2l-10 9.8 10.6 18.2h-12.1l-5.7-11.2 -4 3.9v7.3h ...
#             var script = document.createElement("script"); script.async = true;script.trackTdsCookie=true,script.fingerprint=false,script.src = "//static.naukri.com/s/0/1/j/ub_v1.11.min.js";script.onload = function() { ub.init({
#                    trackTdsCookie : true, beaconUrl : "https://logs.naukri.com/uba", bulkBeaconUrl : "https://logs.naukri.com/collectorapi/v1/uba/bulk", queuedEvents:queuedEvents, queuedSuperProps:queuedSuperProps,  tenantId:'1' , autoTrack:false, blackList:
#                 []
#             }); };document.head.appendChild(script);}()); ub.register({ appId:109, pageName: "jobsearch",  tenantId:'1' , }); </script>   <script>
#     //hack of IE and safari bug : Super expression must either be null or a function, not undefined
#     if (typeof HTMLElement !== 'function') {
#         var _HTMLElement = function() {};
#         _HTMLElement.prototype = HTMLElement.prototype;
#         HTMLElement = _HTMLElement;
#     }
#     </script> <script src="//static.naukri.com/s/7/109/j/vendors~main.7d082bee.min.js" type="text/javascript" defer></script> <script src="//static.naukri.com/s/7/109/j/main.3d561068.min.js" type="text/javascript" defer></script> <script type="text/javascript" src="//static.naukri.com/s/0/0/j/nLoggerJB_v3.0.min.js"></script> <script type="text/javascript">
#    window.nLogger && nLogger.init({ "tag": "revamped_srp", "nLogger": { "beaconUrl": "https:\/\/lg.naukri.com\/uba", "eventName": "newMonkError", "deviceType": "SERVER" }, "boomerang": { "logBW": false, "beaconUrl": "https:\/\/lg.naukri.com\/uba", "imageURL": "\/\/static.naukri.com\/s\/0\/0\/i\/", "eventName": "newMonkPerformance", "deviceType": "SERVER" }, "tenantId": 1, "appId": 109, "userIP": "2045974146" });
#  </script> <script type="text/javascript">
#    (function(w, d, s, l, i) {
#      w[l] = w[l] || [];
#      w[l].push({
#          'gtm.start': new Date().getTime(),
#          event: 'gtm.js'
#      });
#      var f = d.getElementsByTagName(s)[0],
#          j = d.createElement(s),
#          dl = l != 'dataLayer' ? '&l=' + l : '';
#      j.defer = 'defer';
#      j.src =
#          'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#      f.parentNode.insertBefore(j, f);
#    })(window, document, 'script', 'dataLayer', 'GTM-NX744H');
#  </script> <script defer src='https://www.googletagservices.com/tag/js/gpt.js'></script> <script>
#           var googletag = googletag || {};
#           googletag.cmd = googletag.cmd || [];
#     </script> <script type="text/javascript"  src="/HL871sifcxYG/DdQjhx/ih6fqq/SEEwVLpr/dAkaXGd6/LGYA/ZE1hHHsB"></script></body> </html>

# %%
url="https://www.naukri.com/data-science-jobs"
from selenium import webdriver
browser = webdriver.Chrome()

# %%
browser.get(url)
html=browser.page_source

# %%
html_parsable=BeautifulSoup(html,'html.parser')

# %%
title=[]
for i in html_parsable.find_all("article",class_="jobTuple bgWhite br4 mb-8"):
    for j in i.find_all("div",class_="jobTupleHeader"):
        title.append(j.a.text)

# %%
salary=[]
for i in html_parsable.find_all("article",class_="jobTuple bgWhite br4 mb-8"):
    for j in i.find_all("div",class_="jobTupleHeader"):
        salary.append(j.find_all("li")[1].text.strip())

# %%
exp=[]
for i in html_parsable.find_all("article",class_="jobTuple bgWhite br4 mb-8"):
    for j in i.find_all("div",class_="jobTupleHeader"):
        exp.append(j.find_all("li")[0].text.strip())

# %%
company=[]
for i in html_parsable.find_all("article",class_="jobTuple bgWhite br4 mb-8"):
    for j in i.find_all("div",class_="jobTupleHeader"):
        company.append(j.find("div").find_all("a")[1].text.strip())

# %%
loc=[]
for i in html_parsable.find_all("article",class_="jobTuple bgWhite br4 mb-8"):
    for j in i.find_all("div",class_="jobTupleHeader"):
        loc.append(j.find_all("li")[2].text.strip())

# %%
import pandas as pd
table=pd.DataFrame({'title':title,'salary':salary,'exp':exp,'org':company,'loc':loc})

# %%
table.head()
# Out:
#                                              title                     salary  \
# 0  Data Science & Analysis (Technology Management)              Not disclosed
# 1                      Senior Analyst-Data Science              Not disclosed
# 2                  Software Engineer- Data Science              Not disclosed
# 3                            Data Science Engineer  75,00,000 - 90,00,000 PA.
# 4                  Technical leader - Data Science              Not disclosed
#
#         exp                                                org  \
# 0   3-6 Yrs        Morgan Stanley Advantage Services Pvt. Ltd.
# 1   5-8 Yrs                                          Accenture
# 2   0-1 Yrs                                        Evalueserve
# 3   1-4 Yrs  Dell International Services India  Private Lim...
# 4  5-12 Yrs                                              Intel
#
#                                      loc
# 0                    Bangalore/Bengaluru
# 1                    Bangalore/Bengaluru
# 2  Gurgaon/Gurugram, Bangalore/Bengaluru
# 3                    Bangalore/Bengaluru
# 4                    Bangalore/Bengaluru

# %%
### Class Excercise: Scrape the information from first 4 pages
def get_data(soup):
    title=[]
    salary=[]
    exp = []
    company = []
    loc = []
    for i in soup.find_all("article",class_="jobTuple bgWhite br4 mb-8"):
        for j in i.find_all("div",class_="jobTupleHeader"):
            title.append(j.a.text)
    for i in soup.find_all("article",class_="jobTuple bgWhite br4 mb-8"):
        for j in i.find_all("div",class_="jobTupleHeader"):
            salary.append(j.find_all("li")[1].text.strip())
    for i in soup.find_all("article",class_="jobTuple bgWhite br4 mb-8"):
        for j in i.find_all("div",class_="jobTupleHeader"):
            exp.append(j.find_all("li")[0].text.strip())
    for i in soup.find_all("article",class_="jobTuple bgWhite br4 mb-8"):
        for j in i.find_all("div",class_="jobTupleHeader"):
            company.append(j.find("div").find_all("a")[1].text.strip())
    for i in soup.find_all("article",class_="jobTuple bgWhite br4 mb-8"):
        for j in i.find_all("div",class_="jobTupleHeader"):
            loc.append(j.find_all("li")[2].text.strip())
    table=pd.DataFrame()
    table['title']=title
    table['company']=company
    table['exp']=exp
    table['loc']=loc
    table['salary']=salary
    return table

# %%
browser = webdriver.Chrome()
browser.get(url)
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
get_data(soup)
# Out:
#                                                 title  \
# 0     Data Science & Analysis (Technology Management)
# 1                         Senior Analyst-Data Science
# 2                     Software Engineer- Data Science
# 3                               Data Science Engineer
# 4                     Technical leader - Data Science
# 5                                Analyst-Data Science
# 6          Analyst & Lead For Data Science - Datorama
# 7     P&A/DAS - Core Data Science - Associate Manager
# 8                Data Science - Analyst / Sr. Analyst
# 9        P&A/DAS - Core Data Science - Senior Analyst
# 10                               Manager Data Science
# 11                           ML Data Science Engineer
# 12                               Data Science Manager
# 13                  Team Lead/Consultant-Data Science
# 14                             Principle Data Science
# 15                  Team Lead/Consultant-Data Science
# 16  ACN - Applied Intelligence - Solutions.AI - Da...
# 17                        Senior Analyst-Data Science
# 18                        Senior Analyst-Data Science
# 19                        Senior Analyst-Data Science
#
#                                               company       exp  \
# 0         Morgan Stanley Advantage Services Pvt. Ltd.   3-6 Yrs
# 1                                           Accenture   5-8 Yrs
# 2                                         Evalueserve   0-1 Yrs
# 3   Dell International Services India  Private Lim...   1-4 Yrs
# 4                                               Intel  5-12 Yrs
# 5                                           Accenture   3-5 Yrs
# 6           Omnicom Media Group India Private Limited   3-8 Yrs
# 7                                           Accenture   2-5 Yrs
# 8                        BLUCOGNITION PRIVATE LIMITED   2-3 Yrs
# 9                                           Accenture   2-5 Yrs
# 10                         Reliance Jio Infocomm Ltd.  8-11 Yrs
# 11            Sollys Consulting and Solutions Pvt Ltd   4-6 Yrs
# 12                                            CoLearn   4-7 Yrs
# 13                                          Accenture  7-11 Yrs
# 14                                         Kaleidofin  8-13 Yrs
# 15                                          Accenture  7-11 Yrs
# 16                                          Accenture   4-9 Yrs
# 17                                          Accenture   5-8 Yrs
# 18                                          Accenture   5-8 Yrs
# 19                                          Accenture   5-8 Yrs
#
#                                                   loc  \
# 0                                 Bangalore/Bengaluru
# 1                                 Bangalore/Bengaluru
# 2               Gurgaon/Gurugram, Bangalore/Bengaluru
# 3                                 Bangalore/Bengaluru
# 4                                 Bangalore/Bengaluru
# 5                                 Bangalore/Bengaluru
# 6   Hyderabad/Secunderabad, Bangalore/Bengaluru, D...
# 7                                 Bangalore/Bengaluru
# 8                              Pune(WFH during Covid)
# 9                                              Mumbai
# 10                                Bangalore/Bengaluru
# 11                  Mumbai, Pune, Bangalore/Bengaluru
# 12                                Bangalore/Bengaluru
# 13                                Bangalore/Bengaluru
# 14                       Chennai, Bangalore/Bengaluru
# 15                                Bangalore/Bengaluru
# 16                                Bangalore/Bengaluru
# 17                                Bangalore/Bengaluru
# 18                                Bangalore/Bengaluru
# 19                                Bangalore/Bengaluru
#
#                        salary
# 0               Not disclosed
# 1               Not disclosed
# 2               Not disclosed
# 3   75,00,000 - 90,00,000 PA.
# 4               Not disclosed
# 5               Not disclosed
# 6               Not disclosed
# 7               Not disclosed
# 8               Not disclosed
# 9               Not disclosed
# 10              Not disclosed
# 11              Not disclosed
# 12              Not disclosed
# 13              Not disclosed
# 14              Not disclosed
# 15              Not disclosed
# 16              Not disclosed
# 17              Not disclosed
# 18              Not disclosed
# 19              Not disclosed

# %%
browser.close()

# %%
from tqdm import tqdm
import time
base_url="https://www.naukri.com/data-science-jobs-{}"
master=[]
for i in tqdm(range(1,5)):
    url=base_url.format(i)
    browser = webdriver.Chrome()
    browser.get(url)
    time.sleep(1)
    html=browser.page_source
    browser.close()
    soup=BeautifulSoup(html,'html.parser')
    master.append(get_data(soup))
# Out:
# 100%|█████████████████████████████████████████████| 4/4 [02:15<00:00, 33.81s/it]

# %%
pd.concat([i for i in master])
# Out:
#                                                 title  \
# 0     Data Science & Analysis (Technology Management)
# 1                         Senior Analyst-Data Science
# 2                     Software Engineer- Data Science
# 3                               Data Science Engineer
# 4                     Technical leader - Data Science
# ..                                                ...
# 15  Sr. Vice President - Analytics - Data Science ...
# 16                     Senior Associate(Data Science)
# 17                    Sr. Data Science Engineer, SMAI
# 18  Assistant / Associate Professor Data Science &...
# 19                             Analyst - Data Science
#
#                                               company       exp  \
# 0         Morgan Stanley Advantage Services Pvt. Ltd.   3-6 Yrs
# 1                                           Accenture   5-8 Yrs
# 2                                         Evalueserve   0-1 Yrs
# 3   Dell International Services India  Private Lim...   1-4 Yrs
# 4                                               Intel  5-12 Yrs
# ..                                                ...       ...
# 15                          Huquo Consulting Pvt. Ltd  8-13 Yrs
# 16                  KARYA CONSULTANTS PRIVATE LIMITED   2-5 Yrs
# 17                  Micron Semiconductor Asia Pte Ltd  5-10 Yrs
# 18                                    Krea University   1-4 Yrs
# 19                            Nuware  Systems Pvt Ltd   3-6 Yrs
#
#                                       loc                     salary
# 0                     Bangalore/Bengaluru              Not disclosed
# 1                     Bangalore/Bengaluru              Not disclosed
# 2   Gurgaon/Gurugram, Bangalore/Bengaluru              Not disclosed
# 3                     Bangalore/Bengaluru  75,00,000 - 90,00,000 PA.
# 4                     Bangalore/Bengaluru              Not disclosed
# ..                                    ...                        ...
# 15                       Gurgaon/Gurugram              Not disclosed
# 16                 Hyderabad/Secunderabad              Not disclosed
# 17                 Hyderabad/Secunderabad              Not disclosed
# 18                               Chittoor              Not disclosed
# 19                              Bengaluru              Not disclosed
#
# [80 rows x 5 columns]

# %% [markdown]
# ## Extracting data from html tables

# %%
### Scraping tables
url="https://www.imdb.com/chart/toptv/?ref_=nv_tvv_250"
browser = webdriver.Chrome()
browser.get(url)

# %%
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')

# %%
browser.close()

# %%
tables=soup.find_all("table",class_="chart full-width")
len(tables)
# Out:
# 1

# %%
title=[]
year=[]
rating=[]
for row in tables[0].find_all("tr")[1:]:
    data=row.find_all("td")
    title.append(data[1].a.text)
    year.append(data[1].span.text)
    rating.append(data[2].text.strip())

# %%
table=pd.DataFrame({'title':title,'year':year,'rating':rating})

# %%
table.head()
# Out:
#               title    year rating
# 0   Planet Earth II  (2016)    9.5
# 1      Planet Earth  (2006)    9.4
# 2      Breaking Bad  (2008)    9.4
# 3  Band of Brothers  (2001)    9.4
# 4         Chernobyl  (2019)    9.3

# %%
url="https://en.wikipedia.org/wiki/List_of_terrorist_incidents_in_August_2019"
browser=webdriver.Chrome()
browser.get(url)
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')

# %%
browser.close()
len(soup.find_all("table",class_='wikitable'))
# Out:
# 1

# %%
tables=soup.find_all("table",class_='wikitable')

# %%
len(tables)
# Out:
# 1

# %%
date=[]
typ=[]
dead=[]
inj=[]
loc=[]
details=[]
perp=[]
partof=[]
for row in tables[0].find_all("tr")[1:]:
    data=row.find_all("td")
    date.append(data[0].text.strip())
    typ.append(data[1].text.strip())
    dead.append(data[2].text.strip())
    inj.append(data[3].text.strip())
    loc.append(data[4].text.strip())
    details.append(data[5].text.strip())
    perp.append(data[6].text.strip())
    partof.append(data[7].text.strip())
terror=pd.DataFrame()
terror['date']=date
terror['type']=typ
terror['dead']=dead
terror['inj']=inj
terror['loc']=loc
terror['details']=details
terror['perp']=perp
terror['partof']=partof

# %%
### Extracting links:
url="https://en.wikipedia.org/wiki/List_of_terrorist_incidents"
browser=webdriver.Chrome()
browser.get(url)
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
browser.close()

# %%
links=soup.find_all("div",class_="div-col")

# %%
len(links)
# Out:
# 2

# %%
partial_links=[]
for link in links[0].find_all("li"):
    partial_links.append(link.a['href'])

# %%
partial_links=pd.Series(partial_links)

# %%
partial_links[partial_links=="/wiki/List_of_terrorist_incidents_in_2015"]
# Out:
# 45    /wiki/List_of_terrorist_incidents_in_2015
# dtype: object

# %%
rel_partial_links=partial_links[45:]

# %%
base_url="https://en.wikipedia.org{}"

# %%
def get_data(soup,i):
    tables=soup.find_all("table",class_='wikitable')
    date=[]
    typ=[]
    dead=[]
    inj=[]
    loc=[]
    details=[]
    perp=[]
    partof=[]
    for row in tables[0].find_all("tr")[1:]:
        data=row.find_all("td")
        date.append(data[0].text.strip())
        typ.append(data[1].text.strip())
        dead.append(data[2].text.strip())
        inj.append(data[3].text.strip())
        loc.append(data[4].text.strip())
        details.append(data[5].text.strip())
        perp.append(data[6].text.strip())
        try:
            partof.append(data[7].text.strip())
        except:
            partof.append("none")
    terror=pd.DataFrame()
    terror['date']=date
    terror['type']=typ
    terror['dead']=dead
    terror['inj']=inj
    terror['loc']=loc
    terror['details']=details
    terror['perp']=perp
    terror['partof']=partof
    terror['url']=i
    return terror

# %%
master=[]
browser = webdriver.Chrome()
from tqdm import tqdm
for i in tqdm(rel_partial_links):
    url=base_url.format(i)
    browser.get(url)
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    master.append(get_data(soup,i))
browser.close()
# Out:
# 100%|█████████████████████████████████████████████| 7/7 [00:09<00:00,  1.29s/it]

# %%
pd.concat([i for i in master])
# Out:
#            date             type               dead      inj  \
# 0       3–7 Jan         Massacre  UnknownEst. 2000+  Unknown
# 1         5 Jan  Suicide bombing             3 (+2)        2
# 2         6 Jan  Suicide bombing             1 (+1)        1
# 3         7 Jan         Car bomb            37 / 38       66
# 4         7 Jan    Mass shooting                 12       11
# ..          ...              ...                ...      ...
# 12  3 September         Stabbing             0 (+1)        7
# 13   15 October         Stabbing                  1        0
# 14   20 October          Bombing                 14        3
# 15   7 November     Drone strike                  0        6
# 16  14 November  Suicide bombing             0 (+1)        1
#
#                            loc                                        details  \
# 0   Baga, Borno State, Nigeria                             2015 Baga massacre
# 1           Arar, Saudi Arabia                       January 2015 Arar attack
# 2             Istanbul, Turkey          January 2015 Istanbul suicide bombing
# 3                Sana'a, Yemen                    January 2015 Sana'a bombing
# 4                Paris, France                         Charlie Hebdo shooting
# ..                         ...                                            ...
# 12       Auckland, New Zealand               2021 Auckland Countdown stabbing
# 13       Leigh-on-Sea, England                         Killing of David Amess
# 14             Damascus, Syria                      2021 Damascus bus bombing
# 15               Baghdad, Iraq  Attempted assassination of Mustafa Al-Kadhimi
# 16          Liverpool, England             Liverpool Women's Hospital bombing
#
#                                                  perp  \
# 0   Boko Haram militants opened fire on northern N...
# 1   Two gunmen, one strapped with a suicide vest, ...
# 2   A female suicide bomber detonated her explosiv...
# 3   A car bomb detonated in front of a police acad...
# 4   Two heavily armed gunmen entered the Paris off...
# ..                                                ...
# 12  At 14:40 NZST, seven people were stabbed at th...
# 13  MP David Amess was stabbed multiple times outs...
# 14  A double bombing of a Syrian Army bus in the S...
# 15  A failed attempt to assassinate Iraqi Prime Mi...
# 16  A IED exploded in a taxi as it arrived at main...
#
#                                            partof  \
# 0                                      Boko Haram
# 1                                ISIL (suspected)
# 2                                           DHKPC
# 3   al-Qaeda in the Arabian Peninsula (suspected)
# 4            al-Qaeda in the Arabian Peninsula[8]
# ..                                            ...
# 12                        ISIL-inspired lone wolf
# 13
# 14                             Saraya Qasioun[30]
# 15                                        Unknown
# 16
#
#                                           url
# 0   /wiki/List_of_terrorist_incidents_in_2015
# 1   /wiki/List_of_terrorist_incidents_in_2015
# 2   /wiki/List_of_terrorist_incidents_in_2015
# 3   /wiki/List_of_terrorist_incidents_in_2015
# 4   /wiki/List_of_terrorist_incidents_in_2015
# ..                                        ...
# 12  /wiki/List_of_terrorist_incidents_in_2021
# 13  /wiki/List_of_terrorist_incidents_in_2021
# 14  /wiki/List_of_terrorist_incidents_in_2021
# 15  /wiki/List_of_terrorist_incidents_in_2021
# 16  /wiki/List_of_terrorist_incidents_in_2021
#
# [514 rows x 9 columns]

# %%
big_table = pd.concat([i for i in master])

# %%
### By, year, month,date how many terror incidents have happened
big_table['month']=big_table['url'].map(lambda x:x.split("_")[5])
big_table['year']=big_table['url'].map(lambda x:x.split("_")[-1])
big_table['country']=big_table['loc'].map(lambda x:x.split(",")[-1])

# %%
big_table.head()
# Out:
#       date             type               dead      inj  \
# 0  3–7 Jan         Massacre  UnknownEst. 2000+  Unknown
# 1    5 Jan  Suicide bombing             3 (+2)        2
# 2    6 Jan  Suicide bombing             1 (+1)        1
# 3    7 Jan         Car bomb            37 / 38       66
# 4    7 Jan    Mass shooting                 12       11
#
#                           loc                                details  \
# 0  Baga, Borno State, Nigeria                     2015 Baga massacre
# 1          Arar, Saudi Arabia               January 2015 Arar attack
# 2            Istanbul, Turkey  January 2015 Istanbul suicide bombing
# 3               Sana'a, Yemen            January 2015 Sana'a bombing
# 4               Paris, France                 Charlie Hebdo shooting
#
#                                                 perp  \
# 0  Boko Haram militants opened fire on northern N...
# 1  Two gunmen, one strapped with a suicide vest, ...
# 2  A female suicide bomber detonated her explosiv...
# 3  A car bomb detonated in front of a police acad...
# 4  Two heavily armed gunmen entered the Paris off...
#
#                                           partof  \
# 0                                     Boko Haram
# 1                               ISIL (suspected)
# 2                                          DHKPC
# 3  al-Qaeda in the Arabian Peninsula (suspected)
# 4           al-Qaeda in the Arabian Peninsula[8]
#
#                                          url month  year        country
# 0  /wiki/List_of_terrorist_incidents_in_2015  2015  2015        Nigeria
# 1  /wiki/List_of_terrorist_incidents_in_2015  2015  2015   Saudi Arabia
# 2  /wiki/List_of_terrorist_incidents_in_2015  2015  2015         Turkey
# 3  /wiki/List_of_terrorist_incidents_in_2015  2015  2015          Yemen
# 4  /wiki/List_of_terrorist_incidents_in_2015  2015  2015         France

# %%
big_table['inj'].unique()
# Out:
# array(['Unknown', '2', '1', '66', '11', '9', '18', '12', '', '108',
#        '500+', '6', '10–12', '139', '40+', '351', '28', '79', '115', '0',
#        '37', '13', '102', '40', '300+', '227', '27', '3', '4', '17',
#        '67+', '130', '104', 'unknown', '16', '212', '20', '123', '3 (+1)',
#        '60+', '97-150+', '50', '508', '22', '200+', '368', '5', '7', '23',
#        '35', '80', '3–12', '35+', '200', '1 (+1)', '19', '25', '24',
#        '56+', '60', '65', '110', '61', '100+', '180', 'Unknown (+6)',
#        '33', '125', '36', '340', '21', '347', '86', '75', '165+', '30+',
#        '20+', '194+', '~15', 'Around 220 kidnapped', '55', '37+', '30',
#        '18 (+1)', '42+ more kidnapped', '53', '25+', '8', '239', '246+',
#        '75+', '434', '10+', '260+', '171+', '77 (+3)', '15', '130+',
#        '50+', '70', '109', '32 (+1)', '10', '44+', '117+', '119', '102+',
#        '95', '30 (+17)', '177', '70+', '155', '47', '63', '122', '~42',
#        '87', '43+', '90+', '12+', '63+', '120+', '64', '14', '160+',
#        '800+', '413+', '48', '52', '54', '6(+1)', '26', '32', '152', '93',
#        '316', '11 (+1)', 'Dozens', '128+', '57', '105', '235', '143',
#        '85', '120', '58', '186', '+1 (+Unknown)', '2 (+1)', '91', '165',
#        '43', '6 (+1)', '56', '68', '58–70', '49', '1 Kidnapped',
#        '270–400+', '6[95]', '45', '650+', '142', 'Several', '150+', '82',
#        '78', '136', '0 (+1)', '240'], dtype=object)

# %%
import re

# %%
pattern=re.compile(r'\d{1,3}')

# %%
import numpy as np
def get_injured(row):
    if len(re.findall(pattern,row))==0:
        return np.nan
    elif len(re.findall(pattern,row))==1:
        return re.findall(pattern,row)[0]
    else:
        els=re.findall(pattern,row)
        els=list(map(lambda x:float(x),els))
        els=np.mean(els)
        return els

# %%
big_table['inj'].map(lambda x: re.findall(pattern,x)).head(2)
# Out:
# 0     []
# 1    [2]
# Name: inj, dtype: object

# %%
big_table['inj'].map(get_injured).head()
# Out:
# 0    NaN
# 1      2
# 2      1
# 3     66
# 4     11
# Name: inj, dtype: object
