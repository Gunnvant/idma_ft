# %% [markdown]
# ## **Session5: Working with web apis**
#
# - Using api service which doesn't require any authentication
# - Using api service which require authentication
#
# **Using api service which doesn't require authentication**
# Web apis are a very popular way of exposing data. So one of the motivations of learning to fetch data from the web-apis is to be able to fetch data.
#
# API access can be ```open``` or be behind some kind of ```authorisation```. We will first look at the open web api and how to access the data.
#
# We will be using [this](https://covidtracking.com/data/api/version-2) as an example of data fetch from an open web api.
#
# **API Endpoints**
#
# An api endpoint is just a url which one needs to ```hit``` to get the data. For example [here](https://covidtracking.com/data/api/version-2) you can see that to access a single day of data we need to
# hit the following endpoint:
#
# - URL path:/v2/us/daily/[date-iso-format].json
# - Example: https://api.covidtracking.com/v2/us/daily/2021-01-02.json
# - Simplified data:/v2/us/daily/[date-iso-format].json
# - Simplified data example: https://api.covidtracking.com/v2/us/daily/2021-01-02/simple.json
#
# Lets hit this endpoint.

# %%
import requests
import json
date = "2021-01-02"
base_url = "https://api.covidtracking.com"
end_point = f"/v2/us/daily/{date}.json"
url = base_url+end_point
resp = requests.get(url).json()

# %%
resp
# Out:
# {'meta': {'build_time': '2021-06-01T07:03:25.055Z',
#   'license': 'CC-BY-4.0',
#   'version': '2.0-beta',
#   'field_definitions': [{'name': 'Total test results',
#     'field': 'tests.pcr.total',
#     'deprecated': False,
#     'prior_names': ['totalTestResults']},
#    {'name': 'Hospital discharges', 'deprecated': False, 'prior_names': []},
#    {'name': 'Confirmed Cases',
#     'field': 'cases.confirmed',
#     'deprecated': False,
#     'prior_names': ['positiveCasesViral']},
#    {'name': 'Cumulative hospitalized/Ever hospitalized',
#     'field': 'outcomes.hospitalized.total',
#     'deprecated': False,
#     'prior_names': ['hospitalizedCumulative']},
#    {'name': 'Cumulative in ICU/Ever in ICU',
#     'field': 'outcomes.hospitalized.in_icu',
#     'deprecated': False,
#     'prior_names': ['inIcuCumulative']},
#    {'name': 'Cumulative on ventilator/Ever on ventilator',
#     'field': 'hospitalization.on_ventilator.cumulative',
#     'deprecated': False,
#     'prior_names': ['onVentilatorCumulative']},
#    {'name': 'Currently hospitalized/Now hospitalized',
#     'field': 'hospitalization.hospitalized.currently',
#     'deprecated': False,
#     'prior_names': ['hospitalizedCurrently']},
#    {'name': 'Currently in ICU/Now in ICU',
#     'field': 'hospitalization.in_icu.currently',
#     'deprecated': False,
#     'prior_names': ['inIcuCurrently']},
#    {'name': 'Currently on ventilator/Now on ventilator',
#     'field': 'hospitalization.on_ventilator.currently',
#     'deprecated': False,
#     'prior_names': ['onVentilatorCurrently']},
#    {'name': 'Deaths (probable)',
#     'field': 'outcomes.death.probable',
#     'deprecated': False,
#     'prior_names': ['deathProbable']},
#    {'name': 'Deaths (confirmed)',
#     'field': 'outcomes.death.confirmed',
#     'deprecated': False,
#     'prior_names': ['deathConfirmed']},
#    {'name': 'Deaths (confirmed and probable)',
#     'field': 'outcomes.death.cumulative',
#     'deprecated': False,
#     'prior_names': ['death']},
#    {'name': 'Probable Cases', 'deprecated': False, 'prior_names': []},
#    {'name': 'Last Update (ET)',
#     'field': 'meta.updated',
#     'deprecated': False,
#     'prior_names': ['lastUpdateEt', 'lastUpdateTime', 'checkTimeEt']},
#    {'name': 'New deaths',
#     'field': 'outcomes.death.calculated.change_from_prior_day',
#     'deprecated': False,
#     'prior_names': ['deathIncrease']},
#    {'name': 'Date',
#     'field': 'date',
#     'deprecated': False,
#     'prior_names': ['dateModified']}]},
#  'data': {'date': '2021-01-02',
#   'states': 56,
#   'cases': {'total': {'value': 20327598,
#     'calculated': {'population_percent': 6.1451,
#      'change_from_prior_day': 280318,
#      'seven_day_change_percent': 7.6}}},
#   'testing': {'total': {'value': 257729806,
#     'calculated': {'population_percent': 77.9127,
#      'change_from_prior_day': 1934350,
#      'seven_day_change_percent': 4.4}}},
#   'outcomes': {'hospitalized': {'currently': {'value': 123614,
#      'calculated': {'population_percent': 0.0374,
#       'change_from_prior_day': -1433,
#       'seven_day_change_percent': 5.3,
#       'seven_day_average': 123416}},
#     'in_icu': {'currently': {'value': 23133,
#       'calculated': {'population_percent': 0.007,
#        'change_from_prior_day': -122,
#        'seven_day_change_percent': 3.4,
#        'seven_day_average': 22917}}},
#     'on_ventilator': {'currently': {'value': 7910,
#       'calculated': {'population_percent': 0.0024,
#        'change_from_prior_day': -80,
#        'seven_day_change_percent': 1.3,
#        'seven_day_average': 7935}}}},
#    'death': {'total': {'value': 341800,
#      'calculated': {'population_percent': 0.1033,
#       'change_from_prior_day': 2406,
#       'seven_day_change_percent': 5.7,
#       'seven_day_average': 333178}}}}}}

# %% [markdown]
# As you can see that response is in a json format and it can be easily parsed to create a tabular view out of it.
#
# **Class Excercise**:
# 1. Use the all state metadata to create a tabular view of each state and its code.
# 2. Now write a function which takes the state code and gives the data for a given state in the following format
#
#
# | date     | total_cases |confirmed_cases |tests_pcr_total|tests_antibody_total|hospitalized_currently|on_ventilator_currently|death_confirmed|
# | ----------- | ----------- |-------|--------------|---------------|--------------------|--------|-------|
#
# 3. Using the function defined above and the state codes, collect the data for all the states and store it in a csv.

# %%
url = "https://api.covidtracking.com/v2/states.json"
resp = requests.get(url).json()

# %%
states = []
codes = []
for state in resp['data']:
    states.append(state['name'])
    codes.append(state['state_code'])
import pandas as pd
codes = pd.DataFrame({'state':states,'code':codes})

# %%
def get_state_data(state_code):
    url = f'https://api.covidtracking.com/v2/states/{state_code.lower()}/daily/simple.json'
    raw_data = requests.get(url).json()
    return raw_data
def parse_raw_data(raw_data):
    dates = []
    tot_cases = []
    confirmed_cases = []
    tests_pcr_total = []
    tests_antibody_total = []
    hosp_currently = []
    on_ventilator_currently = []
    deaths = []
    rel_data = raw_data['data']
    for d in rel_data:
        dates.append(d['date'])
        tot_cases.append(d['cases']['total'])
        confirmed_cases.append(d['cases']['confirmed'])
        tests_pcr_total.append(d['tests']['pcr']['total'])
        tests_antibody_total.append(d['tests']['antibody']['encounters']['total'])
        hosp_currently.append(d['outcomes']['hospitalized']['currently'])
        on_ventilator_currently.append(d['outcomes']['hospitalized']['on_ventilator']['currently'])
        deaths.append(d['outcomes']['death']['confirmed'])
    parsed_data = {'dates':dates,
                  'total_cases':tot_cases,
                  'confirmed_cases':confirmed_cases,
                  'tests_pcr_total':tests_pcr_total,
                  'tests_antibody_total':tests_antibody_total,
                  'hospitalized_currently':hosp_currently,
                  'on_ventilator_currently':on_ventilator_currently,
                  'deaths':deaths}
    return parsed_data

# %%
codes.head(2)
# Out:
#      state code
# 0   Alaska   AK
# 1  Alabama   AL

# %%
raw_data = get_state_data('AK')

# %%
parsed_data = parse_raw_data(raw_data)

# %%
from tqdm import tqdm
tables = []
for state in tqdm(codes['code']):
    raw_data = get_state_data(state)
    parsed_data = parse_raw_data(raw_data)
    table = pd.DataFrame(parsed_data)
    table['state']=state
    tables.append(table)
# Out:
# 100%|███████████████████████████████████████████| 56/56 [00:22<00:00,  2.44it/s]

# %%
pd.concat([t for t in tables]).reset_index()
# Out:
#        index       dates  total_cases confirmed_cases  tests_pcr_total  \
# 0          0  2021-03-07      56886.0            None        1731628.0
# 1          1  2021-03-06      56886.0            None        1731628.0
# 2          2  2021-03-05      56886.0            None        1731628.0
# 3          3  2021-03-04      56745.0            None        1724484.0
# 4          4  2021-03-03      56605.0            None        1711018.0
# ...      ...         ...          ...             ...              ...
# 20775    367  2020-03-05          NaN             NaN              8.0
# 20776    368  2020-03-04          NaN             NaN              4.0
# 20777    369  2020-03-03          NaN             NaN              1.0
# 20778    370  2020-03-02          NaN             NaN              1.0
# 20779    371  2020-03-01          NaN             NaN              1.0
#
#       tests_antibody_total hospitalized_currently on_ventilator_currently  \
# 0                     None                   33.0                     2.0
# 1                     None                   33.0                     2.0
# 2                     None                   33.0                     2.0
# 3                     None                   32.0                     2.0
# 4                     None                   26.0                     2.0
# ...                    ...                    ...                     ...
# 20775                 None                    NaN                    None
# 20776                 None                    NaN                    None
# 20777                 None                    NaN                    None
# 20778                 None                    NaN                    None
# 20779                 None                    NaN                    None
#
#       deaths state
# 0        NaN    AK
# 1        NaN    AK
# 2        NaN    AK
# 3        NaN    AK
# 4        NaN    AK
# ...      ...   ...
# 20775   None    WY
# 20776   None    WY
# 20777   None    WY
# 20778   None    WY
# 20779   None    WY
#
# [20780 rows x 10 columns]

# %% [markdown]
# ## Using API service which requires authetication
#
# - [Use openweathermap api](https://openweathermap.org/api)
# - Create a secret key
# - Use the countrysjon to see the city and countryid

# %%
key = "f56a989e6824d6e4eb7c5e19a63f28ea"
city = "New Delhi"
url=f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={key}"
resp = requests.get(url).json()

# %%
resp
# Out:
# {'coord': {'lon': 77.2311, 'lat': 28.6128},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 295.6,
#   'feels_like': 294.45,
#   'temp_min': 295.6,
#   'temp_max': 295.6,
#   'pressure': 1017,
#   'humidity': 21,
#   'sea_level': 1017,
#   'grnd_level': 992},
#  'visibility': 10000,
#  'wind': {'speed': 2.07, 'deg': 303, 'gust': 4.23},
#  'clouds': {'all': 49},
#  'dt': 1638197107,
#  'sys': {'country': 'IN', 'sunrise': 1638149097, 'sunset': 1638186848},
#  'timezone': 19800,
#  'id': 1261481,
#  'name': 'New Delhi',
#  'cod': 200}

# %%
lat = 28.61282
lon = 77.23114
time = 1586468027
url=f"https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&appid={key}&units=metric"
resp = requests.get(url).json()

# %%
resp
# Out:
# {'lat': 28.6128,
#  'lon': 77.2311,
#  'timezone': 'Asia/Kolkata',
#  'timezone_offset': 19800,
#  'current': {'dt': 1638197794,
#   'sunrise': 1638149097,
#   'sunset': 1638186848,
#   'temp': 22.45,
#   'feels_like': 21.3,
#   'pressure': 1017,
#   'humidity': 21,
#   'dew_point': -0.82,
#   'uvi': 0,
#   'clouds': 49,
#   'visibility': 10000,
#   'wind_speed': 2.07,
#   'wind_deg': 303,
#   'wind_gust': 4.23,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}]},
#  'minutely': [{'dt': 1638197820, 'precipitation': 0},
#   {'dt': 1638197880, 'precipitation': 0},
#   {'dt': 1638197940, 'precipitation': 0},
#   {'dt': 1638198000, 'precipitation': 0},
#   {'dt': 1638198060, 'precipitation': 0},
#   {'dt': 1638198120, 'precipitation': 0},
#   {'dt': 1638198180, 'precipitation': 0},
#   {'dt': 1638198240, 'precipitation': 0},
#   {'dt': 1638198300, 'precipitation': 0},
#   {'dt': 1638198360, 'precipitation': 0},
#   {'dt': 1638198420, 'precipitation': 0},
#   {'dt': 1638198480, 'precipitation': 0},
#   {'dt': 1638198540, 'precipitation': 0},
#   {'dt': 1638198600, 'precipitation': 0},
#   {'dt': 1638198660, 'precipitation': 0},
#   {'dt': 1638198720, 'precipitation': 0},
#   {'dt': 1638198780, 'precipitation': 0},
#   {'dt': 1638198840, 'precipitation': 0},
#   {'dt': 1638198900, 'precipitation': 0},
#   {'dt': 1638198960, 'precipitation': 0},
#   {'dt': 1638199020, 'precipitation': 0},
#   {'dt': 1638199080, 'precipitation': 0},
#   {'dt': 1638199140, 'precipitation': 0},
#   {'dt': 1638199200, 'precipitation': 0},
#   {'dt': 1638199260, 'precipitation': 0},
#   {'dt': 1638199320, 'precipitation': 0},
#   {'dt': 1638199380, 'precipitation': 0},
#   {'dt': 1638199440, 'precipitation': 0},
#   {'dt': 1638199500, 'precipitation': 0},
#   {'dt': 1638199560, 'precipitation': 0},
#   {'dt': 1638199620, 'precipitation': 0},
#   {'dt': 1638199680, 'precipitation': 0},
#   {'dt': 1638199740, 'precipitation': 0},
#   {'dt': 1638199800, 'precipitation': 0},
#   {'dt': 1638199860, 'precipitation': 0},
#   {'dt': 1638199920, 'precipitation': 0},
#   {'dt': 1638199980, 'precipitation': 0},
#   {'dt': 1638200040, 'precipitation': 0},
#   {'dt': 1638200100, 'precipitation': 0},
#   {'dt': 1638200160, 'precipitation': 0},
#   {'dt': 1638200220, 'precipitation': 0},
#   {'dt': 1638200280, 'precipitation': 0},
#   {'dt': 1638200340, 'precipitation': 0},
#   {'dt': 1638200400, 'precipitation': 0},
#   {'dt': 1638200460, 'precipitation': 0},
#   {'dt': 1638200520, 'precipitation': 0},
#   {'dt': 1638200580, 'precipitation': 0},
#   {'dt': 1638200640, 'precipitation': 0},
#   {'dt': 1638200700, 'precipitation': 0},
#   {'dt': 1638200760, 'precipitation': 0},
#   {'dt': 1638200820, 'precipitation': 0},
#   {'dt': 1638200880, 'precipitation': 0},
#   {'dt': 1638200940, 'precipitation': 0},
#   {'dt': 1638201000, 'precipitation': 0},
#   {'dt': 1638201060, 'precipitation': 0},
#   {'dt': 1638201120, 'precipitation': 0},
#   {'dt': 1638201180, 'precipitation': 0},
#   {'dt': 1638201240, 'precipitation': 0},
#   {'dt': 1638201300, 'precipitation': 0},
#   {'dt': 1638201360, 'precipitation': 0},
#   {'dt': 1638201420, 'precipitation': 0}],
#  'hourly': [{'dt': 1638194400,
#    'temp': 22.57,
#    'feels_like': 21.4,
#    'pressure': 1017,
#    'humidity': 20,
#    'dew_point': -1.32,
#    'uvi': 0,
#    'clouds': 49,
#    'visibility': 10000,
#    'wind_speed': 2.17,
#    'wind_deg': 315,
#    'wind_gust': 4.64,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1638198000,
#    'temp': 22.45,
#    'feels_like': 21.3,
#    'pressure': 1017,
#    'humidity': 21,
#    'dew_point': -0.82,
#    'uvi': 0,
#    'clouds': 49,
#    'visibility': 10000,
#    'wind_speed': 2.07,
#    'wind_deg': 303,
#    'wind_gust': 4.23,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1638201600,
#    'temp': 22.35,
#    'feels_like': 21.22,
#    'pressure': 1017,
#    'humidity': 22,
#    'dew_point': -0.34,
#    'uvi': 0,
#    'clouds': 50,
#    'visibility': 10000,
#    'wind_speed': 2.17,
#    'wind_deg': 298,
#    'wind_gust': 4.41,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1638205200,
#    'temp': 22.03,
#    'feels_like': 20.86,
#    'pressure': 1017,
#    'humidity': 22,
#    'dew_point': -0.57,
#    'uvi': 0,
#    'clouds': 54,
#    'visibility': 10000,
#    'wind_speed': 2.49,
#    'wind_deg': 300,
#    'wind_gust': 5.37,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638208800,
#    'temp': 21.48,
#    'feels_like': 20.28,
#    'pressure': 1017,
#    'humidity': 23,
#    'dew_point': -0.44,
#    'uvi': 0,
#    'clouds': 60,
#    'visibility': 10000,
#    'wind_speed': 2.71,
#    'wind_deg': 305,
#    'wind_gust': 6.18,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638212400,
#    'temp': 20.71,
#    'feels_like': 19.49,
#    'pressure': 1016,
#    'humidity': 25,
#    'dew_point': 0,
#    'uvi': 0,
#    'clouds': 90,
#    'visibility': 10000,
#    'wind_speed': 2.7,
#    'wind_deg': 312,
#    'wind_gust': 6.37,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638216000,
#    'temp': 19.8,
#    'feels_like': 18.51,
#    'pressure': 1016,
#    'humidity': 26,
#    'dew_point': -0.46,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.59,
#    'wind_deg': 312,
#    'wind_gust': 6.09,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638219600,
#    'temp': 19.38,
#    'feels_like': 18.05,
#    'pressure': 1016,
#    'humidity': 26,
#    'dew_point': -0.57,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.51,
#    'wind_deg': 308,
#    'wind_gust': 5.94,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638223200,
#    'temp': 18.99,
#    'feels_like': 17.65,
#    'pressure': 1016,
#    'humidity': 27,
#    'dew_point': -0.59,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.65,
#    'wind_deg': 305,
#    'wind_gust': 6.2,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638226800,
#    'temp': 18.63,
#    'feels_like': 17.25,
#    'pressure': 1015,
#    'humidity': 27,
#    'dew_point': -0.52,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.78,
#    'wind_deg': 303,
#    'wind_gust': 6.53,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638230400,
#    'temp': 18.3,
#    'feels_like': 16.92,
#    'pressure': 1015,
#    'humidity': 28,
#    'dew_point': -0.38,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.95,
#    'wind_deg': 308,
#    'wind_gust': 6.89,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638234000,
#    'temp': 18.01,
#    'feels_like': 16.62,
#    'pressure': 1016,
#    'humidity': 29,
#    'dew_point': -0.2,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.88,
#    'wind_deg': 306,
#    'wind_gust': 6.78,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638237600,
#    'temp': 17.94,
#    'feels_like': 16.57,
#    'pressure': 1017,
#    'humidity': 30,
#    'dew_point': 0.06,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.82,
#    'wind_deg': 306,
#    'wind_gust': 6.47,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638241200,
#    'temp': 18.79,
#    'feels_like': 17.48,
#    'pressure': 1017,
#    'humidity': 29,
#    'dew_point': 0.25,
#    'uvi': 0.53,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 3.19,
#    'wind_deg': 307,
#    'wind_gust': 6.55,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638244800,
#    'temp': 20.29,
#    'feels_like': 19.05,
#    'pressure': 1018,
#    'humidity': 26,
#    'dew_point': 0.29,
#    'uvi': 1.48,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 3.26,
#    'wind_deg': 308,
#    'wind_gust': 5.74,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638248400,
#    'temp': 21.92,
#    'feels_like': 20.79,
#    'pressure': 1018,
#    'humidity': 24,
#    'dew_point': 0.37,
#    'uvi': 2.76,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 3.34,
#    'wind_deg': 308,
#    'wind_gust': 5.44,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638252000,
#    'temp': 23.45,
#    'feels_like': 22.43,
#    'pressure': 1017,
#    'humidity': 22,
#    'dew_point': 0.32,
#    'uvi': 3.8,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 3.45,
#    'wind_deg': 305,
#    'wind_gust': 5.23,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638255600,
#    'temp': 24.74,
#    'feels_like': 23.77,
#    'pressure': 1016,
#    'humidity': 19,
#    'dew_point': 0.01,
#    'uvi': 4.17,
#    'clouds': 90,
#    'visibility': 10000,
#    'wind_speed': 3.57,
#    'wind_deg': 309,
#    'wind_gust': 5.05,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638259200,
#    'temp': 25.69,
#    'feels_like': 24.78,
#    'pressure': 1015,
#    'humidity': 18,
#    'dew_point': -0.46,
#    'uvi': 3.62,
#    'clouds': 86,
#    'visibility': 10000,
#    'wind_speed': 3.73,
#    'wind_deg': 313,
#    'wind_gust': 5.09,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638262800,
#    'temp': 26.09,
#    'feels_like': 26.09,
#    'pressure': 1014,
#    'humidity': 17,
#    'dew_point': -0.85,
#    'uvi': 2.44,
#    'clouds': 91,
#    'visibility': 10000,
#    'wind_speed': 3.63,
#    'wind_deg': 317,
#    'wind_gust': 4.68,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638266400,
#    'temp': 26.02,
#    'feels_like': 26.02,
#    'pressure': 1014,
#    'humidity': 17,
#    'dew_point': -0.99,
#    'uvi': 1.2,
#    'clouds': 93,
#    'visibility': 10000,
#    'wind_speed': 3.36,
#    'wind_deg': 318,
#    'wind_gust': 4.14,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638270000,
#    'temp': 25.36,
#    'feels_like': 24.42,
#    'pressure': 1014,
#    'humidity': 18,
#    'dew_point': -0.57,
#    'uvi': 0.35,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 2.91,
#    'wind_deg': 319,
#    'wind_gust': 3.8,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638273600,
#    'temp': 24.26,
#    'feels_like': 23.26,
#    'pressure': 1015,
#    'humidity': 20,
#    'dew_point': -0.46,
#    'uvi': 0,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 2.36,
#    'wind_deg': 324,
#    'wind_gust': 4.14,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638277200,
#    'temp': 23.54,
#    'feels_like': 22.5,
#    'pressure': 1015,
#    'humidity': 21,
#    'dew_point': -0.28,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.64,
#    'wind_deg': 322,
#    'wind_gust': 2.57,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638280800,
#    'temp': 23.06,
#    'feels_like': 21.97,
#    'pressure': 1016,
#    'humidity': 21,
#    'dew_point': -0.18,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.31,
#    'wind_deg': 319,
#    'wind_gust': 1.36,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638284400,
#    'temp': 22.73,
#    'feels_like': 21.63,
#    'pressure': 1016,
#    'humidity': 22,
#    'dew_point': -0.13,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.37,
#    'wind_deg': 314,
#    'wind_gust': 1.4,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638288000,
#    'temp': 22.35,
#    'feels_like': 21.22,
#    'pressure': 1016,
#    'humidity': 22,
#    'dew_point': -0.12,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.42,
#    'wind_deg': 306,
#    'wind_gust': 1.48,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638291600,
#    'temp': 21.93,
#    'feels_like': 20.78,
#    'pressure': 1016,
#    'humidity': 23,
#    'dew_point': -0.16,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.47,
#    'wind_deg': 311,
#    'wind_gust': 1.71,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638295200,
#    'temp': 21.47,
#    'feels_like': 20.27,
#    'pressure': 1016,
#    'humidity': 23,
#    'dew_point': -0.2,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.58,
#    'wind_deg': 295,
#    'wind_gust': 2.11,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638298800,
#    'temp': 21.04,
#    'feels_like': 19.83,
#    'pressure': 1016,
#    'humidity': 24,
#    'dew_point': -0.28,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.89,
#    'wind_deg': 310,
#    'wind_gust': 3.34,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638302400,
#    'temp': 20.67,
#    'feels_like': 19.42,
#    'pressure': 1016,
#    'humidity': 24,
#    'dew_point': -0.35,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.48,
#    'wind_deg': 330,
#    'wind_gust': 2.68,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638306000,
#    'temp': 20.18,
#    'feels_like': 18.91,
#    'pressure': 1016,
#    'humidity': 25,
#    'dew_point': -0.41,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.27,
#    'wind_deg': 340,
#    'wind_gust': 1.94,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638309600,
#    'temp': 19.91,
#    'feels_like': 18.61,
#    'pressure': 1015,
#    'humidity': 25,
#    'dew_point': -0.48,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.92,
#    'wind_deg': 3,
#    'wind_gust': 2.98,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638313200,
#    'temp': 19.75,
#    'feels_like': 18.46,
#    'pressure': 1015,
#    'humidity': 26,
#    'dew_point': -0.52,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.49,
#    'wind_deg': 355,
#    'wind_gust': 2.32,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638316800,
#    'temp': 19.58,
#    'feels_like': 18.27,
#    'pressure': 1016,
#    'humidity': 26,
#    'dew_point': -0.57,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.75,
#    'wind_deg': 3,
#    'wind_gust': 1.26,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638320400,
#    'temp': 19.5,
#    'feels_like': 18.18,
#    'pressure': 1016,
#    'humidity': 26,
#    'dew_point': -0.59,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.54,
#    'wind_deg': 48,
#    'wind_gust': 0.78,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638324000,
#    'temp': 19.51,
#    'feels_like': 18.2,
#    'pressure': 1017,
#    'humidity': 26,
#    'dew_point': -0.45,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.86,
#    'wind_deg': 93,
#    'wind_gust': 1.15,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638327600,
#    'temp': 20.01,
#    'feels_like': 18.75,
#    'pressure': 1018,
#    'humidity': 26,
#    'dew_point': -0.26,
#    'uvi': 0.34,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.38,
#    'wind_deg': 122,
#    'wind_gust': 0.55,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638331200,
#    'temp': 20.76,
#    'feels_like': 19.52,
#    'pressure': 1019,
#    'humidity': 24,
#    'dew_point': -0.37,
#    'uvi': 1.18,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.35,
#    'wind_deg': 169,
#    'wind_gust': 0.62,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638334800,
#    'temp': 21.66,
#    'feels_like': 20.48,
#    'pressure': 1019,
#    'humidity': 23,
#    'dew_point': -0.44,
#    'uvi': 2.19,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.51,
#    'wind_deg': 189,
#    'wind_gust': 0.75,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638338400,
#    'temp': 22.22,
#    'feels_like': 21.07,
#    'pressure': 1018,
#    'humidity': 22,
#    'dew_point': -0.52,
#    'uvi': 3.01,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.2,
#    'wind_deg': 304,
#    'wind_gust': 0.5,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638342000,
#    'temp': 22.75,
#    'feels_like': 21.63,
#    'pressure': 1017,
#    'humidity': 21,
#    'dew_point': -0.67,
#    'uvi': 3.28,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.02,
#    'wind_deg': 1,
#    'wind_gust': 1.06,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638345600,
#    'temp': 22.92,
#    'feels_like': 21.82,
#    'pressure': 1016,
#    'humidity': 21,
#    'dew_point': -0.75,
#    'uvi': 2.84,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.69,
#    'wind_deg': 5,
#    'wind_gust': 2.04,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638349200,
#    'temp': 23.6,
#    'feels_like': 22.54,
#    'pressure': 1015,
#    'humidity': 20,
#    'dew_point': -0.84,
#    'uvi': 1.91,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.02,
#    'wind_deg': 12,
#    'wind_gust': 2.43,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638352800,
#    'temp': 23.69,
#    'feels_like': 22.64,
#    'pressure': 1015,
#    'humidity': 20,
#    'dew_point': -0.63,
#    'uvi': 0.85,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.95,
#    'wind_deg': 14,
#    'wind_gust': 2.36,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638356400,
#    'temp': 23.22,
#    'feels_like': 22.15,
#    'pressure': 1015,
#    'humidity': 21,
#    'dew_point': -0.1,
#    'uvi': 0.25,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.57,
#    'wind_deg': 24,
#    'wind_gust': 1.91,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1638360000,
#    'temp': 22.48,
#    'feels_like': 21.38,
#    'pressure': 1015,
#    'humidity': 23,
#    'dew_point': 0.22,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 0.72,
#    'wind_deg': 38,
#    'wind_gust': 1.08,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1638363600,
#    'temp': 22.03,
#    'feels_like': 20.92,
#    'pressure': 1016,
#    'humidity': 24,
#    'dew_point': 0.55,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.02,
#    'wind_deg': 13,
#    'wind_gust': 1.3,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0}],
#  'daily': [{'dt': 1638167400,
#    'sunrise': 1638149097,
#    'sunset': 1638186848,
#    'moonrise': 1638128640,
#    'moonset': 1638174780,
#    'moon_phase': 0.81,
#    'temp': {'day': 24.07,
#     'min': 18.69,
#     'max': 26.2,
#     'night': 21.48,
#     'eve': 23.61,
#     'morn': 19.02},
#    'feels_like': {'day': 23.13, 'night': 20.28, 'eve': 22.52, 'morn': 18.02},
#    'pressure': 1019,
#    'humidity': 23,
#    'dew_point': 1.91,
#    'wind_speed': 3.47,
#    'wind_deg': 323,
#    'wind_gust': 6.18,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': 48,
#    'pop': 0,
#    'uvi': 4.3},
#   {'dt': 1638253800,
#    'sunrise': 1638235544,
#    'sunset': 1638273244,
#    'moonrise': 1638218640,
#    'moonset': 1638263160,
#    'moon_phase': 0.84,
#    'temp': {'day': 23.45,
#     'min': 17.94,
#     'max': 26.09,
#     'night': 21.47,
#     'eve': 24.26,
#     'morn': 18.3},
#    'feels_like': {'day': 22.43, 'night': 20.27, 'eve': 23.26, 'morn': 16.92},
#    'pressure': 1017,
#    'humidity': 22,
#    'dew_point': 0.32,
#    'wind_speed': 3.73,
#    'wind_deg': 313,
#    'wind_gust': 6.89,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 96,
#    'pop': 0,
#    'uvi': 4.17},
#   {'dt': 1638340200,
#    'sunrise': 1638321990,
#    'sunset': 1638359642,
#    'moonrise': 1638308880,
#    'moonset': 1638351660,
#    'moon_phase': 0.88,
#    'temp': {'day': 22.22,
#     'min': 19.5,
#     'max': 23.69,
#     'night': 20.5,
#     'eve': 22.48,
#     'morn': 19.58},
#    'feels_like': {'day': 21.07, 'night': 19.36, 'eve': 21.38, 'morn': 18.27},
#    'pressure': 1018,
#    'humidity': 22,
#    'dew_point': -0.52,
#    'wind_speed': 2.02,
#    'wind_deg': 12,
#    'wind_gust': 3.34,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 100,
#    'pop': 0,
#    'uvi': 3.28},
#   {'dt': 1638426600,
#    'sunrise': 1638408436,
#    'sunset': 1638446041,
#    'moonrise': 1638399240,
#    'moonset': 1638440400,
#    'moon_phase': 0.92,
#    'temp': {'day': 22.11,
#     'min': 19.31,
#     'max': 23.54,
#     'night': 21.24,
#     'eve': 22.46,
#     'morn': 19.46},
#    'feels_like': {'day': 20.98, 'night': 20.07, 'eve': 21.36, 'morn': 18.22},
#    'pressure': 1018,
#    'humidity': 23,
#    'dew_point': 0.15,
#    'wind_speed': 2.45,
#    'wind_deg': 327,
#    'wind_gust': 4.11,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 100,
#    'pop': 0,
#    'uvi': 3.61},
#   {'dt': 1638513000,
#    'sunrise': 1638494882,
#    'sunset': 1638532442,
#    'moonrise': 1638489840,
#    'moonset': 1638529380,
#    'moon_phase': 0.96,
#    'temp': {'day': 24.77,
#     'min': 20.52,
#     'max': 26.63,
#     'night': 21.87,
#     'eve': 25.14,
#     'morn': 20.52},
#    'feels_like': {'day': 23.8, 'night': 20.87, 'eve': 24.26, 'morn': 19.31},
#    'pressure': 1017,
#    'humidity': 19,
#    'dew_point': -0.65,
#    'wind_speed': 1.62,
#    'wind_deg': 304,
#    'wind_gust': 2.49,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': 58,
#    'pop': 0,
#    'uvi': 4.05},
#   {'dt': 1638599400,
#    'sunrise': 1638581327,
#    'sunset': 1638618844,
#    'moonrise': 1638580620,
#    'moonset': 1638618900,
#    'moon_phase': 0,
#    'temp': {'day': 24.87,
#     'min': 19.75,
#     'max': 26.93,
#     'night': 22.51,
#     'eve': 25.57,
#     'morn': 19.75},
#    'feels_like': {'day': 24.09, 'night': 21.65, 'eve': 24.89, 'morn': 18.64},
#    'pressure': 1016,
#    'humidity': 26,
#    'dew_point': 4.05,
#    'wind_speed': 0.97,
#    'wind_deg': 161,
#    'wind_gust': 1.24,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 5},
#   {'dt': 1638685800,
#    'sunrise': 1638667771,
#    'sunset': 1638705248,
#    'moonrise': 1638671400,
#    'moonset': 1638708840,
#    'moon_phase': 0.04,
#    'temp': {'day': 24.59,
#     'min': 20.03,
#     'max': 26.58,
#     'night': 21.12,
#     'eve': 25.21,
#     'morn': 20.03},
#    'feels_like': {'day': 24.04, 'night': 20.49, 'eve': 24.65, 'morn': 19.11},
#    'pressure': 1014,
#    'humidity': 36,
#    'dew_point': 8.73,
#    'wind_speed': 3.04,
#    'wind_deg': 147,
#    'wind_gust': 5.48,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 0,
#    'pop': 0.54,
#    'rain': 0.53,
#    'uvi': 5},
#   {'dt': 1638772200,
#    'sunrise': 1638754215,
#    'sunset': 1638791653,
#    'moonrise': 1638761940,
#    'moonset': 1638799200,
#    'moon_phase': 0.08,
#    'temp': {'day': 23.66,
#     'min': 19.23,
#     'max': 25.68,
#     'night': 21.1,
#     'eve': 24.58,
#     'morn': 19.23},
#    'feels_like': {'day': 23.1, 'night': 20.28, 'eve': 23.9, 'morn': 18.59},
#    'pressure': 1016,
#    'humidity': 39,
#    'dew_point': 8.82,
#    'wind_speed': 2.73,
#    'wind_deg': 327,
#    'wind_gust': 5.18,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 0,
#    'pop': 0.39,
#    'rain': 0.11,
#    'uvi': 5}]}

# %%
import datetime
datetime.datetime.fromtimestamp(1638772200).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-12-06 12:00:00'
